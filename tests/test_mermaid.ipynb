# %% [markdown]
# SPDX-License-Identifier: Apache-2.0
# Copyright Contributors to the ODPi Egeria project.
#
#
#
# Notebook provides a simple example of using the pyegeria mermaid_utilities functions.
#
# A running Egeria environment is needed to run these functions.
#
# * mermaid_graph(process_guid, view_server, url, user_id, password) - generates Mermaid markdown for the Egeria process.
# * load_mermaid() - must be executed once per session to inject mermaid javascript code into the Jupyter environment.
# * render_mermaid(mermaid_code) - renders and displays the Mermaid markdown code specified.

# %%
from pyegeria import load_mermaid, render_mermaid, generate_process_graph
load_mermaid()
mermaid_graph = generate_process_graph('39dbedae-7753-4d05-9a7a-4a6c80cb02f5')

render_mermaid(mermaid_graph)
# Out:
#     <script src="https://unpkg.com/mermaid@11.4.1/dist/mermaid.min.js"></script>
#     <script>
#         document.addEventListener('DOMContentLoaded', function() {
#             mermaid.initialize({startOnLoad: true});
#         });
#     </script>
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /Users/dwolfson/localGit/egeria-v5-3/egeria-python/pyegeria/mermaid_utilities.py:1290 in         │
# │ generate_process_graph                                                                           │
# │                                                                                                  │
# │   1287 │   token = a_client.create_egeria_bearer_token()                                         │
# │   1288 │   try:                                                                                  │
# │   1289 │   │   start_time = time.perf_counter()                                                  │
# │ ❱ 1290 │   │   response = a_client.get_gov_action_process_graph(process_guid)                    │
# │   1291 │   │   duration = time.perf_counter() - start_time                                       │
# │   1292 │   │                                                                                     │
# │   1293 │   │   if type(response) is dict:                                                        │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │     a_client = <pyegeria.automated_curation_omvs.AutomatedCuration object at 0x119fa7e90>    │ │
# │ │      console = <console width=115 ColorSystem.TRUECOLOR>                                     │ │
# │ │            e = InvalidParameterException('{"class":"GovernanceActionProcessGraphResponse","… │ │
# │ │                The Process entity with unique identifier                                     │ │
# │ │                39dbedae-7753-4d05-9a7a-4a6c80cb02f5 is not found for method                  │ │
# │ │                getGovernanceActionProcessGraph of access service Governance Action Framework │ │
# │ │                Services in open metadata server qs-metadata-store, error message was:        │ │
# │ │                OMRS-REPOSITORY-404-002 The entity identified with guid                       │ │
# │ │                39dbedae-7753-4d05-9a7a-4a6c80cb02f5 passed on the getEntityDetail call is    │ │
# │ │                not known to the open metadata repository                                     │ │
# │ │                Enterprise","exceptionErrorMessageId":"OMAG-REPOSITORY-HANDLER-404-007","exc… │ │
# │ │                Action Framework Services","qs-metadata-store","OMRS-REPOSITORY-404-002 The   │ │
# │ │                entity identified with guid 39dbedae-7753-4d05-9a7a-4a6c80cb02f5 passed on    │ │
# │ │                the getEntityDetail call is not known to the open metadata repository         │ │
# │ │                Enterprise"],"exceptionSystemAction":"The system is unable to update          │ │
# │ │                information associated with the entity because none of the connected open     │ │
# │ │                metadata repositories recognize the entity\'s unique                          │ │
# │ │                identifier.","exceptionUserAction":"The unique identifier of the entity is    │ │
# │ │                supplied by the caller.  Verify that the caller\'s logic is correct, and that │ │
# │ │                there are no errors being reported by the open metadata repository. Once all  │ │
# │ │                errors have been resolved, retry the                                          │ │
# │ │                request.","exceptionProperties":{"parameterName":"processGUID"}}')            │ │
# │ │ process_guid = '39dbedae-7753-4d05-9a7a-4a6c80cb02f5'                                        │ │
# │ │   start_time = 616539.594257958                                                              │ │
# │ │        token = 'eyJraWQiOiI4MjVkNGE3MS05OTUyLTQ1MWQtYTE2Mi1iYjRiZjY3MTY2NDAiLCJhbGciOiJSUzI… │ │
# │ │          url = 'https://localhost:9443'                                                      │ │
# │ │      user_id = 'erinoverview'                                                                │ │
# │ │    user_pass = 'secret'                                                                      │ │
# │ │  view_server = 'qs-view-server'                                                              │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /Users/dwolfson/localGit/egeria-v5-3/egeria-python/pyegeria/automated_curation_omvs.py:1750 in   │
# │ get_gov_action_process_graph                                                                     │
# │                                                                                                  │
# │   1747 │   │                                                                                     │
# │   1748 │   │   """                                                                               │
# │   1749 │   │   loop = asyncio.get_event_loop()                                                   │
# │ ❱ 1750 │   │   response = loop.run_until_complete(                                               │
# │   1751 │   │   │   self._async_get_gov_action_process_graph(process_guid)                        │
# │   1752 │   │   )                                                                                 │
# │   1753 │   │   return response                                                                   │
# │                                                                                                  │
# │ ╭───────────────────────────────────────── locals ──────────────────────────────────────────╮    │
# │ │         loop = <_UnixSelectorEventLoop running=True closed=False debug=False>             │    │
# │ │ process_guid = '39dbedae-7753-4d05-9a7a-4a6c80cb02f5'                                     │    │
# │ │         self = <pyegeria.automated_curation_omvs.AutomatedCuration object at 0x119fa7e90> │    │
# │ ╰───────────────────────────────────────────────────────────────────────────────────────────╯    │
# │                                                                                                  │
# │ /Users/dwolfson/Library/Caches/pypoetry/virtualenvs/pyegeria-EE3A6T0J-py3.12/lib/python3.12/site │
# │ -packages/nest_asyncio.py:98 in run_until_complete                                               │
# │                                                                                                  │
# │    95 │   │   │   if not f.done():                                                               │
# │    96 │   │   │   │   raise RuntimeError(                                                        │
# │    97 │   │   │   │   │   'Event loop stopped before Future completed.')                         │
# │ ❱  98 │   │   │   return f.result()                                                              │
# │    99 │                                                                                          │
# │   100 │   def _run_once(self):                                                                   │
# │   101 │   │   """                                                                                │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │      f = <Task finished name='Task-3'                                                        │ │
# │ │          coro=<AutomatedCuration._async_get_gov_action_process_graph() done, defined at      │ │
# │ │          /Users/dwolfson/localGit/egeria-v5-3/egeria-python/pyegeria/automated_curation_omv… │ │
# │ │          exception=InvalidParameterException('{"class":"GovernanceActionProcessGraphRespons… │ │
# │ │          The Process entity with unique identifier 39dbedae-7753-4d05-9a7a-4a6c80cb02f5 is   │ │
# │ │          not found for method getGovernanceActionProcessGraph of access service Governance   │ │
# │ │          Action Framework Services in open metadata server qs-metadata-store, error message  │ │
# │ │          was: OMRS-REPOSITORY-404-002 The entity identified with guid                        │ │
# │ │          39dbedae-7753-4d05-9a7a-4a6c80cb02f5 passed on the getEntityDetail call is not      │ │
# │ │          known to the open metadata repository                                               │ │
# │ │          Enterprise","exceptionErrorMessageId":"OMAG-REPOSITORY-HANDLER-404-007","exception… │ │
# │ │          Action Framework Services","qs-metadata-store","OMRS-REPOSITORY-404-002 The entity  │ │
# │ │          identified with guid 39dbedae-7753-4d05-9a7a-4a6c80cb02f5 passed on the             │ │
# │ │          getEntityDetail call is not known to the open metadata repository                   │ │
# │ │          Enterprise"],"exceptionSystemAction":"The system is unable to update information    │ │
# │ │          associated with the entity because none of the connected open metadata repositories │ │
# │ │          recognize the entity\'s unique identifier.","exceptionUserAction":"The unique       │ │
# │ │          identifier of the entity is supplied by the caller.  Verify that the caller\'s      │ │
# │ │          logic is correct, and that there are no errors being reported by the open metadata  │ │
# │ │          repository. Once all errors have been resolved, retry the                           │ │
# │ │          request.","exceptionProperties":{"parameterName":"processGUID"}}')>                 │ │
# │ │ future = <coroutine object AutomatedCuration._async_get_gov_action_process_graph at          │ │
# │ │          0x11dac8d60>                                                                        │ │
# │ │   self = <_UnixSelectorEventLoop running=True closed=False debug=False>                      │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /Users/dwolfson/miniconda3/lib/python3.12/asyncio/futures.py:203 in result                       │
# │                                                                                                  │
# │   200 │   │   │   raise exceptions.InvalidStateError('Result is not ready.')                     │
# │   201 │   │   self.__log_traceback = False                                                       │
# │   202 │   │   if self._exception is not None:                                                    │
# │ ❱ 203 │   │   │   raise self._exception.with_traceback(self._exception_tb)                       │
# │   204 │   │   return self._result                                                                │
# │   205 │                                                                                          │
# │   206 │   def exception(self):                                                                   │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ self = <Task finished name='Task-3'                                                          │ │
# │ │        coro=<AutomatedCuration._async_get_gov_action_process_graph() done, defined at        │ │
# │ │        /Users/dwolfson/localGit/egeria-v5-3/egeria-python/pyegeria/automated_curation_omvs.… │ │
# │ │        exception=InvalidParameterException('{"class":"GovernanceActionProcessGraphResponse"… │ │
# │ │        The Process entity with unique identifier 39dbedae-7753-4d05-9a7a-4a6c80cb02f5 is not │ │
# │ │        found for method getGovernanceActionProcessGraph of access service Governance Action  │ │
# │ │        Framework Services in open metadata server qs-metadata-store, error message was:      │ │
# │ │        OMRS-REPOSITORY-404-002 The entity identified with guid                               │ │
# │ │        39dbedae-7753-4d05-9a7a-4a6c80cb02f5 passed on the getEntityDetail call is not known  │ │
# │ │        to the open metadata repository                                                       │ │
# │ │        Enterprise","exceptionErrorMessageId":"OMAG-REPOSITORY-HANDLER-404-007","exceptionEr… │ │
# │ │        Action Framework Services","qs-metadata-store","OMRS-REPOSITORY-404-002 The entity    │ │
# │ │        identified with guid 39dbedae-7753-4d05-9a7a-4a6c80cb02f5 passed on the               │ │
# │ │        getEntityDetail call is not known to the open metadata repository                     │ │
# │ │        Enterprise"],"exceptionSystemAction":"The system is unable to update information      │ │
# │ │        associated with the entity because none of the connected open metadata repositories   │ │
# │ │        recognize the entity\'s unique identifier.","exceptionUserAction":"The unique         │ │
# │ │        identifier of the entity is supplied by the caller.  Verify that the caller\'s logic  │ │
# │ │        is correct, and that there are no errors being reported by the open metadata          │ │
# │ │        repository. Once all errors have been resolved, retry the                             │ │
# │ │        request.","exceptionProperties":{"parameterName":"processGUID"}}')>                   │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /Users/dwolfson/miniconda3/lib/python3.12/asyncio/tasks.py:314 in __step_run_and_handle_result   │
# │                                                                                                  │
# │    311 │   │   │   if exc is None:                                                               │
# │    312 │   │   │   │   # We use the `send` method directly, because coroutines                   │
# │    313 │   │   │   │   # don't have `__iter__` and `__next__` methods.                           │
# │ ❱  314 │   │   │   │   result = coro.send(None)                                                  │
# │    315 │   │   │   else:                                                                         │
# │    316 │   │   │   │   result = coro.throw(exc)                                                  │
# │    317 │   │   except StopIteration as exc:                                                      │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ coro = <coroutine object AutomatedCuration._async_get_gov_action_process_graph at            │ │
# │ │        0x11dac8d60>                                                                          │ │
# │ │ self = None                                                                                  │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /Users/dwolfson/localGit/egeria-v5-3/egeria-python/pyegeria/automated_curation_omvs.py:1725 in   │
# │ _async_get_gov_action_process_graph                                                              │
# │                                                                                                  │
# │   1722 │   │   │   f"governance-action-processes/{process_guid}/graph"                           │
# │   1723 │   │   )                                                                                 │
# │   1724 │   │                                                                                     │
# │ ❱ 1725 │   │   response = await self._async_make_request("POST", url)                            │
# │   1726 │   │   return response.json().get("element", "no actions")                               │
# │   1727 │                                                                                         │
# │   1728 │   def get_gov_action_process_graph(self, process_guid: str) -> dict | str:              │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ process_guid = '39dbedae-7753-4d05-9a7a-4a6c80cb02f5'                                        │ │
# │ │         self = <pyegeria.automated_curation_omvs.AutomatedCuration object at 0x119fa7e90>    │ │
# │ │          url = 'https://localhost:9443/servers/qs-view-server/api/open-metadata/automated-c… │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# │                                                                                                  │
# │ /Users/dwolfson/localGit/egeria-v5-3/egeria-python/pyegeria/_client.py:428 in                    │
# │ _async_make_request                                                                              │
# │                                                                                                  │
# │   425 │   │   │   │   │   │   return response                                                    │
# │   426 │   │   │   │   │   else:                                                                  │
# │   427 │   │   │   │   │   │   exc_message = response.text                                        │
# │ ❱ 428 │   │   │   │   │   │   raise InvalidParameterException(exc_message)                       │
# │   429 │   │   │   │   else:                                                                      │
# │   430 │   │   │   │   │   msg = OMAGCommonErrorCode.CLIENT_SIDE_REST_API_ERROR.value[            │
# │   431 │   │   │   │   │   │   "message_template"                                                 │
# │                                                                                                  │
# │ ╭─────────────────────────────────────────── locals ───────────────────────────────────────────╮ │
# │ │ caller_method = '_async_get_gov_action_process_graph'                                        │ │
# │ │ calling_frame = <frame at 0x11da82f60, file                                                  │ │
# │ │                 '/Users/dwolfson/localGit/egeria-v5-3/egeria-python/pyegeria/automated_cura… │ │
# │ │                 line 1725, code _async_get_gov_action_process_graph>                         │ │
# │ │    class_name = 'Client'                                                                     │ │
# │ │      endpoint = 'https://localhost:9443/servers/qs-view-server/api/open-metadata/automated-… │ │
# │ │   exc_message = '{"class":"GovernanceActionProcessGraphResponse","relatedHTTPCode":404,"exc… │ │
# │ │       payload = None                                                                         │ │
# │ │  related_code = 404                                                                          │ │
# │ │  request_type = 'POST'                                                                       │ │
# │ │      response = <Response [200 ]>                                                            │ │
# │ │          self = <pyegeria.automated_curation_omvs.AutomatedCuration object at 0x119fa7e90>   │ │
# │ │   status_code = 200                                                                          │ │
# │ │      time_out = 30                                                                           │ │
# │ ╰──────────────────────────────────────────────────────────────────────────────────────────────╯ │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# InvalidParameterException: OMAG-REPOSITORY-HANDLER-404-007 The Process entity with unique identifier
# 39dbedae-7753-4d05-9a7a-4a6c80cb02f5 is not found for method getGovernanceActionProcessGraph of access service
# Governance Action Framework Services in open metadata server qs-metadata-store, error message was:
# OMRS-REPOSITORY-404-002 The entity identified with guid 39dbedae-7753-4d05-9a7a-4a6c80cb02f5 passed on the
# getEntityDetail call is not known to the open metadata repository Enterprise
# ---------------------------------------------------------------------------
# InvalidParameterException                 Traceback (most recent call last)
# File ~/localGit/egeria-v5-3/egeria-python/pyegeria/mermaid_utilities.py:1290, in generate_process_graph(process_guid, view_server, url, user_id, user_pass)
#    1289 start_time = time.perf_counter()
# -> 1290 response = a_client.get_gov_action_process_graph(process_guid)
#    1291 duration = time.perf_counter() - start_time
#
# File ~/localGit/egeria-v5-3/egeria-python/pyegeria/automated_curation_omvs.py:1750, in AutomatedCuration.get_gov_action_process_graph(self, process_guid)
#    1749 loop = asyncio.get_event_loop()
# -> 1750 response = loop.run_until_complete(
#    1751     self._async_get_gov_action_process_graph(process_guid)
#    1752 )
#    1753 return response
#
# File ~/Library/Caches/pypoetry/virtualenvs/pyegeria-EE3A6T0J-py3.12/lib/python3.12/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~/miniconda3/lib/python3.12/asyncio/futures.py:203, in Future.result(self)
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~/miniconda3/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     311 if exc is None:
#     312     # We use the `send` method directly, because coroutines
#     313     # don't have `__iter__` and `__next__` methods.
# --> 314     result = coro.send(None)
#     315 else:
#
# File ~/localGit/egeria-v5-3/egeria-python/pyegeria/automated_curation_omvs.py:1725, in AutomatedCuration._async_get_gov_action_process_graph(self, process_guid)
#    1720 url = (
#    1721     f"{self.curation_command_root}/"
#    1722     f"governance-action-processes/{process_guid}/graph"
#    1723 )
# -> 1725 response = await self._async_make_request("POST", url)
#    1726 return response.json().get("element", "no actions")
#
# File ~/localGit/egeria-v5-3/egeria-python/pyegeria/_client.py:428, in Client._async_make_request(self, request_type, endpoint, payload, time_out)
#     427         exc_message = response.text
# --> 428         raise InvalidParameterException(exc_message)
#     429 else:
#
# InvalidParameterException: OMAG-REPOSITORY-HANDLER-404-007 The Process entity with unique identifier 39dbedae-7753-4d05-9a7a-4a6c80cb02f5 is not found for method getGovernanceActionProcessGraph of access service Governance Action Framework Services in open metadata server qs-metadata-store, error message was: OMRS-REPOSITORY-404-002 The entity identified with guid 39dbedae-7753-4d05-9a7a-4a6c80cb02f5 passed on the getEntityDetail call is not known to the open metadata repository Enterprise
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pyegeria import load_mermaid, render_mermaid, generate_process_graph
#       2 load_mermaid()
# ----> 3 mermaid_graph = generate_process_graph('39dbedae-7753-4d05-9a7a-4a6c80cb02f5')
#       5 render_mermaid(mermaid_graph)
#
# File ~/localGit/egeria-v5-3/egeria-python/pyegeria/mermaid_utilities.py:1394, in generate_process_graph(process_guid, view_server, url, user_id, user_pass)
#    1388 except (
#    1389     InvalidParameterException,
#    1390     PropertyServerException,
#    1391     UserNotAuthorizedException,
#    1392 ) as e:
#    1393     console.print_exception(show_locals=True)
# -> 1394     assert False, "Invalid request"
#    1396 finally:
#    1397     a_client.close_session()
#
# AssertionError: Invalid request
