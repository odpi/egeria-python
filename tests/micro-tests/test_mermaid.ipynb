# %% [markdown]
# SPDX-License-Identifier: Apache-2.0
# Copyright Contributors to the ODPi Egeria project.
#
#
#
# Notebook provides a simple example of using the pyegeria mermaid_utilities functions.
#
# A running Egeria environment is needed to run these functions.
#
# * mermaid_graph(process_guid, view_server, url, user_id, password) - generates Mermaid markdown for the Egeria process.
# * load_mermaid() - must be executed once per session to inject mermaid javascript code into the Jupyter environment.
# * render_mermaid(mermaid_code) - renders and displays the Mermaid markdown code specified.

# %%
from pyegeria import load_mermaid, render_mermaid, EgeriaTech
client = EgeriaTech(user_id="peterprofile",user_pwd="secret")
client.create_egeria_bearer_token()
# Out:
# 'eyJraWQiOiJlMThmOGFjOS0xMzY3LTQ5MmEtODU5ZC0wZTNjMWE5ODg2YjkiLCJhbGciOiJSUzI1NiJ9.eyJpc3MiOiJzZWxmIiwic3ViIjoicGV0ZXJwcm9maWxlIiwiZXhwIjoxNzc5MTg1MTQ0LCJpYXQiOjE3NzkxODE1NDQsImRpc3BsYXlOYW1lIjoiUGV0ZXIgUHJvZmlsZSJ9.E9vGxBsjomoejSU7H09VHEuT9mQjcRRsw9JDAvrlVtrzohKl1DG7JCLBbV_Dk5RbHe90edIhlg6LHQhX_Hjc1P1iCkUOVN1DRuOnDMrlblO2XkEzhWanWAZeQoLTHjc0LYSUSIR9re1PLUIKPE8ToqG0SSjn-wllKCzsGZ8EtN3eJiP15NgbAkXCFUP5OkHcCqr1LmcXv8_Nua6O5kdTHpbVUF2OVJ4hB8Srw5Z8T7W1hhDMPHiH6Ow_lcNsWKSpFu-CCSeLCfnp3PFV7Q0b7IV-oP1qRd7i6tq-YbGGIDia8n2cEQPSrE0wLSDFXUh-S9ffPKRkunA9ZifB05GQEA'

# %%
# load_mermaid()
mermaid = client.find_collections("Open Metadata Digital Product Catalog",metadata_element_subtypes=['DigitalProductCatalog'],output_format="MERMAID",report_spec="Collections")

# %%
from pyegeria.view.output_formatter import _normalize_mermaid_graph
from pyegeria import render_mermaid
render_mermaid(mermaid)
# clean = mermaid.replace("```mermaid", "").replace("```", "").strip()
# render_mermaid(_normalize_mermaid_graph(clean))
# Out:
#     <div></div>
#     <div id="mermaid-graph-2fc32bec-7d92" class="mermaid">
#         flowchart TD
# %%{init: {&quot;flowchart&quot;: {&quot;htmlLabels&quot;: false}} }%%
#
# 1(&quot;*Digital Product Catalog*&lt;br/&gt;**Open Metadata Digital Product Catalog**&quot;)
# 2@{ shape: trap-t, label: &quot;*Engine Action*&lt;br/&gt;**baudot-subscription-manager (EgeriaWatchdog)**&quot;}
# 1==&gt;|&quot;Actions&quot;|2
# 3[&quot;*Governance Approach*&lt;br/&gt;**Digital Products**&quot;]
# 1==&gt;|&quot;More Information&quot;|3
# 4[&quot;*Root Collection*&lt;br/&gt;**Digital Product Catalogs Root**&quot;]
# 4==&gt;|&quot;Collection Membership&quot;|1
# 5[&quot;*Data Dictionary*&lt;br/&gt;**Open Metadata Digital Product Data Dictionary**&quot;]
# 1==&gt;|&quot;Collection Membership&quot;|5
# 6[&quot;*Data Field*&lt;br/&gt;**Version Identifier**&quot;]
# 5==&gt;|&quot;Collection Membership&quot;|6
# 7[&quot;*Data Field*&lt;br/&gt;**Informal Tags**&quot;]
# ...
